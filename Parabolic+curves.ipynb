# %%
curve(x^2, from = 0,to = 5)
# Out:
# plot without title

# %%
curve(x^2 + x + 4, from = -10,to=10)
# Out:
# plot without title

# %% [markdown]
# $x^{2} + x  = 4$

# %% [markdown]
# $e^{i\pi} + 1 = 0$

# %%
curve(2*x^2 + 4*x + 16, from =-100,to=100)
# Out:
# plot without title
